><td>ensino fundamental completo</td><td>operador de colheita II</td><td>1800</td></tr><tr><td>01/02/2020</td><td>24457</td><td>26/07/2000</td><td>null</td><td>null</td><td>mestrado</td><td>gerente de produção</td><td>11500</td></tr><tr><td>01/02/2020</td><td>13254</td><td>null</td><td>03/09/2005</td><td>null</td><td>ensino medio incompleto</td><td>operador de colheita I</td><td>1625</td></tr><tr><td>01/02/2020</td><td>57687</td><td>28/05/1991</td><td>18/10/2015</td><td>null</td><td>doutorado</td><td>cientista de dados</td><td>7200</td></tr><tr><td>01/02/2020</td><td>46578</td><td>11/01/1972</td><td>26/11/2009</td><td>null</td><td>ensino superior completo</td><td>analista de sistemas pleno</td><td>7500</td></tr><tr><td>01/02/2020</td><td>59393</td><td>17/05/1998</td><td>08/01/2019</td><td>null</td><td>ensino médio completo</td><td>assistente administrativo</td><td>1400</td></tr><tr><td>01/02/2020</td><td>95847</td><td>23/04/1993</td><td>25/04/2012</td><td>null</td><td>graduação</td><td>líder de tecnologia</td><td>11800</td></tr><tr><td>01/02/2020</td><td>46457</td><td>12/02/1982</td><td>07/11/1998</td><td>null</td><td>pós graduação</td><td>analista de BI</td><td>5900</td></tr><tr><td>01/03/2020</td><td>11223</td><td>01/04/1995</td><td>01/06/2018</td><td>null</td><td>4ª série completo</td><td>operador de colheita I</td><td>1500</td></tr><tr><td>01/03/2020</td><td>13456</td><td>05/03/1960</td><td>11/02/2002</td><td>null</td><td>ensino médio comp</td><td>assistente de rh</td> ...

# %%
#MOSTRANDO OS SCHEMA DOS DADOS.
df2.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- mes_referencia: string (nullable = true)
# -- id_funcionario: integer (nullable = true)
# -- data_de_nascimento: string (nullable = true)
# -- data_de_admissao: string (nullable = true)
# -- data_de_demissao: string (nullable = true)
# -- grau_de_instrucao: string (nullable = true)
# -- cargo: string (nullable = true)
# -- salario: string (nullable = true)
#
# </div>

# %%
#Tirando os valores nulos das colunas
df2 = df2.filter(df2.data_de_nascimento.isNotNull())
df2 = df2.filter(df2.data_de_admissao.isNotNull())
df2 = df2.filter(df2.id_funcionario.isNotNull())
df2 = df2.filter(df2.grau_de_instrucao.isNotNull())
df2 = df2.filter(df2.cargo.isNotNull())
df2 = df2.filter(df2.salario.isNotNull())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Unicidade
# REMOVENDO VALORES DUPLICADOS DAS COLUNAS
df2.dropDuplicates(['id_funcionario', 'mes_referencia', 'data_de_admissao'])
#df2.dropDuplicates(['mes_referencia'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: DataFrame[mes_referencia: string, id_funcionario: int, data_de_nascimento: string, data_de_admissao: string, data_de_demissao: string, grau_de_instrucao: string, cargo: string, salario: string]</div>

# %%
#Integridade
# rode esse comando para a função 
from pyspark import SparkConf, SparkContext
from pyspark.sql import SQLContext, HiveContext
from pyspark.sql import functions as Func

hiveContext = HiveContext(sc)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/spark/python/pyspark/sql/context.py:622: FutureWarning: HiveContext is deprecated in Spark 2.0.0. Please use SparkSession.builder.enableHiveSupport().getOrCreate() instead.
#   warnings.warn(
# </div>

# %%
#integridade dos dados
df2 = df2.withColumn("salario", Func.when(Func.col("salario")=='O líder de tecnologia é uma pessoa maravilhosa, sempre muito atencioso com a equipe e claro em suas expectativas.', 12500).otherwise(Func.col("salario")))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Padronize os valores dentro das colunas:

#1. Valores do tipo texto devem ter a primeira letra de uma palavra no modo maiúsculo;

df2 = df2.withColumn("cargo", Func.when(Func.col("cargo")=='operador de colheita I', 'Operador_de_colheita_I').otherwise(Func.col("cargo")))
df2 = df2.withColumn("cargo", Func.when(Func.col("cargo")=='operador de colheita I', 'Operador_de_colheita_I').otherwise(Func.col("cargo")))
df2 = df2.withColumn("cargo", Func.when(Func.col("cargo")=='gerente de produção', 'Gerente_de_produção').otherwise(Func.col("cargo")))
df2 = df2.withColumn("cargo", Func.when(Func.col("cargo")=='analista de BI', 'Analista_de_BI').otherwise(Func.col("cargo")))
df2 = df2.withColumn("cargo", Func.when(Func.col("cargo")=='analista de sistemas pleno', 'Analista_de_sistemas_pleno').otherwise(Func.col("cargo")))
df2 = df2.withColumn("cargo", Func.when(Func.col("cargo")=='analista de sistemas senior', 'Analista_de_sistemas_senior').otherwise(Func.col("cargo")))
df2 = df2.withColumn("cargo", Func.when(Func.col("cargo")=='assistente administrativo', 'Assistente_administrativo').otherwise(Func.col("cargo")))
df2 = df2.withColumn("cargo", Func.when(Func.col("cargo")=='assistente de rh', 'Assistente_de_rh').otherwise(Func.col("cargo")))
df2 = df2.withColumn("cargo", Func.when(Func.col("cargo")=='cientista de dados', 'Cientista_de_dados').otherwise(Func.col("cargo")))
df2 = df2.withColumn("cargo", Func.when(Func.col("cargo")=='gerente de produção', 'Gerente_de_produção').otherwise(Func.col("cargo")))
df2 = df2.withColumn("cargo", Func.when(Func.col("cargo")=='líder de tecnologia', 'Líder_de_tecnologia').otherwise(Func.col("cargo")))
df2 = df2.withColumn("cargo", Func.when(Func.col("cargo")=='operador de colheita II', 'Operador_de_colheita_II').otherwise(Func.col("cargo")))


df2 = df2.withColumn("grau_de_instrucao", Func.when(Func.col("grau_de_instrucao")=='pós graduação', 'Pós_graduação').otherwise(Func.col("grau_de_instrucao")))
df2 = df2.withColumn("grau_de_instrucao", Func.when(Func.col("grau_de_instrucao")=='mestrado', 'Mestrado').otherwise(Func.col("grau_de_instrucao")))
df2 = df2.withColumn("grau_de_instrucao", Func.when(Func.col("grau_de_instrucao")=='graduação', 'Graduação').otherwise(Func.col("grau_de_instrucao")))
df2 = df2.withColumn("grau_de_instrucao", Func.when(Func.col("grau_de_instrucao")=='ensino superior completo', 'Ensino_superior_completo').otherwise(Func.col("grau_de_instrucao")))
df2 = df2.withColumn("grau_de_instrucao", Func.when(Func.col("grau_de_instrucao")=='ensino médio completo', 'Ensino_médio_completo').otherwise(Func.col("grau_de_instrucao")))
df2 = df2.withColumn("grau_de_instrucao", Func.when(Func.col("grau_de_instrucao")=='ensino medio incompleto', 'Ensino_medio_incompleto').otherwise(Func.col("grau_de_instrucao")))
df2 = df2.withColumn("grau_de_instrucao", Func.when(Func.col("grau_de_instrucao")=='doutorado', 'Doutorado').otherwise(Func.col("grau_de_instrucao")))
df2 = df2.withColumn("grau_de_instrucao", Func.when(Func.col("grau_de_instrucao")=='4ª série completo', '4ª_série_completo').otherwise(Func.col("grau_de_instrucao")))
df2 = df2.withColumn("grau_de_instrucao", Func.when(Func.col("grau_de_instrucao")=='ensino médio comp', 'Ensino_médio_completo').otherwise(Func.col("grau_de_instrucao")))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Convertendo as Colunas

#Float
from pyspark.sql.types import FloatType
df2 = df2.withColumn("salario",
df2["salario"].cast(FloatType()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#criando novas coluna
from pyspark.sql import SparkSession
from pyspark.sql.functions import lit

df2 = df2.select('*', lit(1).alias("Admitido_no_mês"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Transformando arquivo parquet para melhor trabalhar
df2.write.format("parquet").save("/df2")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AnalysisException</span>                         Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-3434584693156509&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      1</span> <span class="ansi-red-fg"># Transformando arquivo parquet para melhor trabalhar</span>
# <span class="ansi-green-fg">----&gt; 2</span><span class="ansi-red-fg"> </span>df2<span class="ansi-blue-fg">.</span>write<span class="ansi-blue-fg">.</span>format<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;parquet&#34;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>save<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;/df2&#34;</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/readwriter.py</span> in <span class="ansi-cyan-fg">save</span><span class="ansi-blue-fg">(self, path, format, mode, partitionBy, **options)</span>
# <span class="ansi-green-intense-fg ansi-bold">    738</span>             self<span class="ansi-blue-fg">.</span>_jwrite<span class="ansi-blue-fg">.</span>save<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    739</span>         <span class="ansi-green-fg">else</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">--&gt; 740</span><span class="ansi-red-fg">             </span>self<span class="ansi-blue-fg">.</span>_jwrite<span class="ansi-blue-fg">.</span>save<span class="ansi-blue-fg">(</span>path<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    741</span>
# <span class="ansi-green-intense-fg ansi-bold">    742</span>     <span class="ansi-blue-fg">@</span>since<span class="ansi-blue-fg">(</span><span class="ansi-cyan-fg">1.4</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/lib/py4j-0.10.9.1-src.zip/py4j/java_gateway.py</span> in <span class="ansi-cyan-fg">__call__</span><span class="ansi-blue-fg">(self, *args)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1302</span>
# <span class="ansi-green-intense-fg ansi-bold">   1303</span>         answer <span class="ansi-blue-fg">=</span> self<span class="ansi-blue-fg">.</span>gateway_client<span class="ansi-blue-fg">.</span>send_command<span class="ansi-blue-fg">(</span>command<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-fg">-&gt; 1304</span><span class="ansi-red-fg">         return_value = get_return_value(
# </span><span class="ansi-green-intense-fg ansi-bold">   1305</span>             answer, self.gateway_client, self.target_id, self.name)
# <span class="ansi-green-intense-fg ansi-bold">   1306</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/utils.py</span> in <span class="ansi-cyan-fg">deco</span><span class="ansi-blue-fg">(*a, **kw)</span>
# <span class="ansi-green-intense-fg ansi-bold">    121</span>                 <span class="ansi-red-fg"># Hide where the exception came from that shows a non-Pythonic</span>
# <span class="ansi-green-intense-fg ansi-bold">    122</span>                 <span class="ansi-red-fg"># JVM exception message.</span>
# <span class="ansi-green-fg">--&gt; 123</span><span class="ansi-red-fg">                 </span><span class="ansi-green-fg">raise</span> converted <span class="ansi-green-fg">from</span> <span class="ansi-green-fg">None</span>
# <span class="ansi-green-intense-fg ansi-bold">    124</span>             <span class="ansi-green-fg">else</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    125</span>                 <span class="ansi-green-fg">raise</span>
#
# <span class="ansi-red-fg">AnalysisException</span>: path dbfs:/df2 already exists.</div>

# %%
# Carregar os arquivo no formato parquet.
df3 = spark.read.format("parquet").load("/df2")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# mostrando os dados carregado.
display(df3)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>mes_referencia</th><th>id_funcionario</th><th>data_de_nascimento</th><th>data_de_admissao</th><th>data_de_demissao</th><th>grau_de_instrucao</th><th>cargo</th><th>salario</th><th>Admitido_no_mês</th><th>Mes_refe</th><th>Mes_adi</th><th>Demitido_no_mês</th><th>Mes_demi</th><th>Idade</th><th>ano_nasc</th><th>refe_ano</th></tr></thead><tbody><tr><td>2020-01-01</td><td>11223</td><td>1995-04-01</td><td>2018-06-01</td><td>null</td><td>4ª_série_completo</td><td>Operador_de_colheita_I</td><td>1500.0</td><td>0</td><td>1</td><td>6</td><td>null</td><td>null</td><td>25</td><td>1995</td><td>2020</td></tr><tr><td>2020-01-01</td><td>13456</td><td>1960-03-05</td><td>2002-02-11</td><td>null</td><td>Ensino_médio_completo</td><td>Assistente_de_rh</td><td>1400.0</td><td>0</td><td>1</td><td>2</td><
td>2010-05-24</td><td>null</td><td>ensino fundamental completo</td><td>Operador_de_colheita_II</td><td>1800.0</td><td>0</td><td>2</td><td>5</td><td>null</td><td>null</td><td>40</td><td>1980</td><td>2020</td></tr><tr><td>2020-02-01</td><td>57687</td><td>1991-05-28</td><td>2015-10-18</td><td>null</td><td>Doutorado</td><td>Cientista_de_dados</td><td>7200.0</td><td>0</td><td>2</td><td>10</td><td>nu ...
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
#TRANFORMANDO AS COLUNAS DO TIPO DATA EM DATA.

from pyspark.sql.functions import *
from pyspark.sql.types import DateType
from pyspark.sql.functions import col, unix_timestamp, to_date

df3 = df3.withColumn('data_de_admissao',to_date(unix_timestamp(col('data_de_admissao'), 'dd/MM/yyyy').cast("timestamp")))
df3 = df3.withColumn('data_de_nascimento',to_date(unix_timestamp(col('data_de_nascimento'), 'dd/MM/yyyy').cast("timestamp")))
df3 = df3.withColumn('mes_referencia',to_date(unix_timestamp(col('mes_referencia'), 'dd/MM/yyyy').cast("timestamp")))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import pyspark  
from pyspark.sql import SparkSession  
from pyspark.sql.functions import *

# Separando os messes para operações e transformando em colunas temporarias.
# aqui iremos pegar os messes da coluna para fazer as operações.

# Mes Refencia
colu = pyspark.sql.functions.split(df3['mes_referencia'], '-')
df3 = df3.withColumn('Mes_refe', colu.getItem(1))

colu1 = pyspark.sql.functions.split(df3['data_de_admissao'], '-')
df3 = df3.withColumn('Mes_adi', colu1.getItem(1))

# Convertendo as strings em integer numeros
from pyspark.sql.types import IntegerType
df3 = df3.withColumn("Mes_refe",
df3["Mes_refe"].cast(IntegerType()))

from pyspark.sql.types import IntegerType
df3 = df3.withColumn("Mes_adi",
df3["Mes_adi"].cast(IntegerType()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# fazendo operações entre as colunas criadas
import pyspark.sql.functions as Func
from  pyspark.sql.types import IntegerType
from pyspark.sql.functions import expr
 
df3 = df3.withColumn('Admitido_no_mês',expr("Mes_refe == Mes_adi"))

# Convertendo a Coluna em Tipo Numérico.
from pyspark.sql.types import IntegerType
df3 = df3.withColumn("Admitido_no_mês",
df3["Admitido_no_mês"].cast(IntegerType()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Demitido no mês: essa coluna deverá ser do tipo numérico, respeitando a seguinte condição: se a data de demissão do registro for igual ao mês de #referência analisado, demitido no mês recebe valor é igual a 1, senão recebe valor igual a 0.

# TENTATIVA

# criando a coluna.
df3 = df3.select('*', lit(0).alias("Demitido_no_mês"))

df3 = df3.withColumn('data_de_demissao',to_date(unix_timestamp(col('data_de_demissao'), 'dd/MM/yyyy').cast("timestamp")))

colu2 = pyspark.sql.functions.split(df3['data_de_demissao'], '-')
df3 = df3.withColumn('Mes_demi', colu2.getItem(1))

df3 = df3.withColumn('Demitido_no_mês',expr("Mes_refe == Mes_demi"))

# Convertendo a Coluna em Tipo Numérico.
from pyspark.sql.types import IntegerType
df3 = df3.withColumn("Demitido_no_mês",
df3["Demitido_no_mês"].cast(IntegerType()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#3. **Idade**: calcule a idade em anos no mês de referência em relação à data de nascimento.#

# Criando uma nova coluna.
df3 = df3.select('*', lit(0).alias("Idade"))

# TENTATIVA

# criando a coluna temporaria.
colu3 = pyspark.sql.functions.split(df3['data_de_nascimento'], '-')
df3 = df3.withColumn('ano_nasc', colu3.getItem(0))

colu4 = pyspark.sql.functions.split(df3['mes_referencia'], '-')
df3 = df3.withColumn('refe_ano', colu4.getItem(0))

df3 = df3.withColumn('Idade',expr("refe_ano - ano_nasc"))

# Convertendo a Coluna em Tipo Numérico.
from pyspark.sql.types import IntegerType
df3 = df3.withColumn("Idade",
df3["Idade"].cast(IntegerType()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#4. **Escolaridade categorizada**: com base na coluna grau de instrução, categorize a escolaridade do colaborador para conter apenas as seguintes categorias: ensino fundamental incompleto, ensino fundamental completo, ensino médio incompleto, ensino médio completo, ensino superior incompleto, ensino superior completo, pós graduação, mestrado, doutorado.

# %%
#. **Tempo de empresa**: com base no mês referência e a data de admissão, obtenha o tempo de empresa do colaborador em meses.

# Criando uma Coluna.
df3 = df3.select('*', lit(0).alias("Tempo_de_empresa"))

colu1 = pyspark.sql.functions.split(df3['data_de_admissao'], '-')
df3 = df3.withColumn('ano_adm', colu1.getItem(0))

#colu2 = pyspark.sql.functions.split(df3['mes_referencia'], '-')
#df3 = df3.withColumn('refe_ano', colu2.getItem(0))

df3 = df3.withColumn('Tempo_de_empresa',expr("refe_ano - ano_adm"))

# Convertendo a Coluna em Tipo Numérico.
from pyspark.sql.types import IntegerType
df3 = df3.withColumn("Tempo_de_empresa",
df3["Tempo_de_empresa"].cast(IntegerType()))

# %%
#6. **Mudou de salário**: compare o salário do mês atual com o salário do mês anterior dos funcionários, se houve mudança atribua 1 como valor para a coluna do mês atual, senão atribua 0.

# eu não entendi essa questão.



#teste


df3 = df3.withColumn('Tateste',expr("id_funcionario || salario"))


#Using CASE WHEN similar to SQL.
from pyspark.sql.functions import expr
df3=df3.withColumn("Mudou_de_salário", expr("CASE WHEN salario = '1500' THEN '0' " 
                                            + "WHEN salario < '1500' THEN '1' "
                                            + "WHEN salario = '1750' THEN '0' "
                                            + "WHEN salario > '1850' THEN '1' " ELSE '0' END"))
df3.show()
 cargo

from pyspark.sql.functions import expr 
df3.filter(expr("id_funcionario == salario")).show()

# %%
#7. **Mudou de cargo**: compare o cargo do mês atual com o cargo do mês anterior dos funcionários, se houve mudança atribua 1 como valor para a coluna do mês atual, senão atribua 0.

df3.select(df3.id_funcionario,df3.cargo)

# %%
# Apagando as Colunas Temporarias que criamos para as operações
df3 = df3.drop(*('refe_ano', 'ano_adm', 'ano_nasc', 'Mes_refe', 'Mes_adi'))

# %%
df3.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- mes_referencia: date (nullable = true)
# -- id_funcionario: integer (nullable = true)
# -- data_de_nascimento: date (nullable = true)
# -- data_de_admissao: date (nullable = true)
# -- data_de_demissao: string (nullable = true)
# -- grau_de_instrucao: string (nullable = true)
# -- cargo: string (nullable = true)
# -- salario: float (nullable = true)
# -- Admitido_no_mês: integer (nullable = true)
# -- Mes_refe: string (nullable = true)
# -- Mes_adi: string (nullable = true)
#
# </div>

# %%
# Resultado Final
# Transformando arquivo parquet para melhor trabalhar
df3.write.format("parquet").save("/df3")

# %%
dfFinal = spark.read.format("parquet").load("/df3")

# %%
display(dfFinal)
